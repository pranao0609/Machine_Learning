# %% [markdown]
# <a href="https://colab.research.google.com/github/pranao0609/Machine_Learning/blob/Linear_Regression/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('read.csv')

# %%
df.head()
# Out:
#    Weight (kg)  Height (cm)
# 0           45          150
# 1           50          152
# 2           48          151
# 3           55          160
# 4           60          162

# %%
##Scatter plot
plt.scatter(df['Weight (kg)'],df['Height (cm)'])

# %%
df.corr()
# Out:
#              Weight (kg)  Height (cm)
# Weight (kg)     1.000000     0.969258
# Height (cm)     0.969258     1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
X=df[['Weight (kg)']] ##independent features should be data frame
y=df['Height (cm)'] ##This variable can be in series

# %%
##Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
## Standardization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
##Apply Linear Regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [10.97802283]
# 167.66666666666666

# %%
##Plot bestfit
plt.scatter(X_train,y_train)

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,lr.predict(X_train),color='red')

# %%
##Prediction fot test
y_pred=lr.predict(X_test)

# %%
##Performance Matrix
from sklearn.metrics import mean_absolute_error,mean_squared_error
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 2.869850537873256
# 27.72599382470604
# 5.265547818100795

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, X_train).fit()

# %%
prediction = model.predict(X_test)
print(prediction)
# Out:
# [-0.96797089 27.24146648 23.09301981  8.98830112 -5.9461069  10.64767979
#  20.60395181 12.30705846  9.81799046 -1.79766022]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:            Height (cm)   R-squared (uncentered):                   0.004
# Model:                            OLS   Adj. R-squared (uncentered):             -0.030
# Method:                 Least Squares   F-statistic:                             0.1243
# Date:                Wed, 11 Dec 2024   Prob (F-statistic):                       0.727
# Time:                        11:32:24   Log-Likelihood:                         -196.23
# No. Observations:                  30   AIC:                                      394.5
# Df Residuals:                      29   BIC:                                      395.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
